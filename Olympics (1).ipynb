# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\Dell\OneDrive\Documents\summer.csv')

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
#1
data = pd.DataFrame(df)
count=0
for City in data['City'].unique():
    count=count+1
print("Total cities participating are:",count)
# Out:
# Total cities participating are: 22

# %%
#2

nex= pd.DataFrame(df)
nex=nex[nex['Medal']=='Gold']
for Sport in nex['Sport'].unique():
   #ans.append([Sport,len(next[next['Sport'] == Sport])])
   nex.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(x = 'Sport', y = 'Medal',figsize=(10,5))

# %%
#3
dat= pd.DataFrame(df)
for Sport in dat['Sport'].unique():
   #ans.append([Sport,len(next[next['Sport'] == Sport])])
   dat.groupby('Sport').count()['Medal'].sort_values(ascending = False).head().plot.bar(x = 'Sport', y = 'Medal',figsize=(15,5))

# %%
#6
data=data[data['Country']=='IND']
data=data[data['Medal']=='Gold']
answer=df.values 
data.iloc[:1, :1]
# Out:
#       Year
# 5512  1928

# %%
#8
ans=[]
next= pd.DataFrame(df)
next=next[next['Gender']=='Women']
next=next[next['Medal']=='Gold']
for Sport in next['Sport'].unique():
   
   next.groupby('Sport').count()['Gender'].sort_values(ascending = False).head().plot.bar(x = 'Sport', y = 'Gender',figsize=(10,5))

# %%
ath=pd.read_csv(r'C:\Users\Dell\OneDrive\Documents\summer.csv')
ath= pd.concat([ath,pd.get_dummies(ath.Medal)],axis=1)
ath['Total'] = ath['Bronze'] + ath['Gold'] + ath['Silver'] 
ath
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
ath.groupby(by=['Athlete'],as_index= False).sum().sort_values(by=['Total'],ascending = False).head(10)
# Out:
#                     Athlete   Year  Bronze  Gold  Silver  Total
# 15702       PHELPS, Michael  44168       2    18       2     22
# 11202      LATYNINA, Larisa  35280       4     9       5     18
# 511      ANDRIANOV, Nikolay  29648       3     7       5     15
# 12476  MANGIAROTTI, Edoardo  25376       2     6       5     13
# 14883          ONO, Takashi  25456       4     5       4     13
# 18114       SHAKHLIN, Boris  25488       2     7       4     13
# 3737      COUGHLIN, Natalie  24080       5     3       4     12
# 14236         NEMOV, Alexei  23976       6     4       2     12
# 9611            KATO, Sawao  23660       1     8       3     12
# 14594          NURMI, Paavo  23084       0     9       3     12

# %%
#4
ath.groupby(by=['Athlete'],as_index= False).sum().sort_values(by=['Total'],ascending = False).head(5).plot.bar(x = 'Athlete', y = 'Total', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
#5
#if ath['']
ath.groupby(by=['Athlete'],as_index= False).sum().sort_values(by=['Gold'],ascending = False).head(5)[['Athlete','Gold']]
# Out:
#                 Athlete  Gold
# 15702   PHELPS, Michael    18
# 14594      NURMI, Paavo     9
# 11202  LATYNINA, Larisa     9
# 18886       SPITZ, Mark     9
# 11538       LEWIS, Carl     9

# %%
#5
ath.groupby(by=['Athlete'],as_index= False).sum().sort_values(by=['Gold'],ascending = False).head(5).plot.bar(x = 'Athlete', y = 'Gold', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
#7
ath.Event.value_counts()[:5]
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
#7
ath.Event.value_counts()[:5].plot.bar(x = 'Event', y = 'Athlete', figsize = (10,5))
# Out:
# <AxesSubplot:>
